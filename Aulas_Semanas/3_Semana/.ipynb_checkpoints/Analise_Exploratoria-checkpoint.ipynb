# %%
import pandas as pd 
import seaborn as sea
import matplotlib.pyplot as plt
from plotnine import *

dados = pd.read_csv('houses_to_rent_v2.csv')

dados.rename(columns= {'rent amount (R$)' : 'valor_aluguel'}, inplace=True)

# %%
dados['valor_aluguel'].mean()
# Out:
# 3896.247194163861

# %%
dados['valor_aluguel'].median()
# Out:
# 2661.0

# %% [markdown]
# #####  Média muito longe da Mediana, logo deve haver algo errado

# %%
dados['valor_aluguel'].std()
# Out:
# 3408.5455176710816

# %%
dados['valor_aluguel'].describe()
# Out:
# count    10692.000000
# mean      3896.247194
# std       3408.545518
# min        450.000000
# 25%       1530.000000
# 50%       2661.000000
# 75%       5000.000000
# max      45000.000000
# Name: valor_aluguel, dtype: float64

# %%
dados['valor_aluguel'].plot(kind = 'hist', bins = 100)

# %%
dados.shape[0]*0.75
# Out:
# 8019.0

# %% [markdown]
# <h4> Distribuição leptocúrtica (b2>0) afunilada em relação à distribuição de Gauss </h4>

# %%
dados.valor_aluguel.kurtosis()
# Out:
# 4.624228179818687

# %% [markdown]
# <h3> Estatística multivariada </h3>

# %%
dados.head()
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 0     São Paulo    70      2         1               1     7      acept
# 1     São Paulo   320      4         4               0    20      acept
# 2  Porto Alegre    80      1         1               1     6      acept
# 3  Porto Alegre    51      2         1               0     2      acept
# 4     São Paulo    25      1         1               0     1  not acept
#
#        furniture  hoa (R$)  valor_aluguel  property tax (R$)  \
# 0      furnished      2065           3300                211
# 1  not furnished      1200           4960               1750
# 2  not furnished      1000           2800                  0
# 3  not furnished       270           1112                 22
# 4  not furnished         0            800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841
# ...

# %% [markdown]
# ##### Qual a cidade com a média de aluguel mais cara?
# ##### Quantos banheiros existem nas residências com alugueis mais caros?
# ##### Os imóveis mais caros são mobiliados?
# ##### Os imóveis mais caros são mobiliados?

# %%
cidades = dados.groupby('city')['valor_aluguel'].mean()
cidades
# Out:
# city
# Belo Horizonte    3664.127981
# Campinas          2364.290739
# Porto Alegre      2337.699916
# Rio de Janeiro    3232.904064
# São Paulo         4652.793783
# Name: valor_aluguel, dtype: float64

# %%
dados[['valor_aluguel','bathroom']].corr(method='spearman')
# Out:
#                valor_aluguel  bathroom
# valor_aluguel        1.00000   0.71589
# bathroom             0.71589   1.00000

# %%
aux = pd.DataFrame({'colunas' : dados.columns, 'tipos' : dados.dtypes})

# %%
colunas_numericas = list(aux[aux['tipos'] == 'int64']['colunas'])

# %%
for coluna in colunas_numericas:
    #Faça correlações entre valor do aluguel e cada coluna
    #Logo precisei pegar quais são as colunas que contém valores numéricos
    #Desta forma conseguis printar as correlações na forma de tabela
    print(dados[['valor_aluguel', coluna]].corr(method = 'spearman'))
# Out:
#                valor_aluguel      area
# valor_aluguel       1.000000  0.728095
# area                0.728095  1.000000
#                valor_aluguel     rooms
# valor_aluguel       1.000000  0.600969
# rooms               0.600969  1.000000
#                valor_aluguel  bathroom
# valor_aluguel        1.00000   0.71589
# bathroom             0.71589   1.00000
#                 valor_aluguel  parking spaces
# valor_aluguel        1.000000        0.620175
# parking spaces       0.620175        1.000000
#                valor_aluguel  hoa (R$)
# valor_aluguel       1.000000  0.355785
# hoa (R$)            0.355785  1.000000
#                valor_aluguel  valor_aluguel
# valor_aluguel            1.0            1.0
# valor_aluguel            1.0            1.0
#                    valor_aluguel  property tax (R$)
# valor_aluguel            1.00000            0.65923
# property tax (R$)        0.65923            1.00000
#                      valor_aluguel  fire insurance (R$)
# ...

# %%
plt.subplots(dpi = 300)
sea.heatmap(dados.corr(), cmap='seismic', annot=True)

# %% [markdown]
# ### Visualização de dados

# %%
dados['parking spaces'].plot(kind='hist', bins=30)

# %%
list(dados)
# Out:
# ['city',
#  'area',
#  'rooms',
#  'bathroom',
#  'parking spaces',
#  'floor',
#  'animal',
#  'furniture',
#  'hoa (R$)',
#  'valor_aluguel',
#  'property tax (R$)',
#  'fire insurance (R$)',
#  'total (R$)']

# %%
sea.countplot(x = 'city', data = dados)

# %%
#ggplot coloca seaborn no chinelo
(ggplot(dados) + aes(x='city') + 
 geom_bar(aes(fill = 'city')))
# Out:
# <ggplot: (-9223371897343406096)>

# %%
plt.figure(figsize=(12,6))
sea.barplot(x = 'city', y = 'valor_aluguel', data = dados.groupby('city')['valor_aluguel'].mean().reset_index())

# %%
#the geom_col must be used if I want to attribute a value to y axis, instead of the geom_bar which uses count stats
(ggplot(dados.groupby('city')['valor_aluguel'].mean().reset_index()) + 
 aes(x = 'city', y='valor_aluguel') + 
 geom_col(aes(fill = 'city')) + 
 ggtitle('Média dos valores de aluguéis por cidade') + 
 theme_bw())
# Out:
# <ggplot: (-9223371897343297476)>

# %% [markdown]
# #### Distplot

# %%
sea.distplot(dados.valor_aluguel)

# %%
(ggplot(dados) + 
 aes(x = 'valor_aluguel') + 
 geom_density(fill = 'blue') + 
 theme_seaborn())
# Out:
# <ggplot: (-9223371897343098712)>

# %% [markdown]
# #### Scatterplot

# %%
dados['aluguel_alto'] = ['Alto' if x > 5000 else 'Baixo' for x in dados['valor_aluguel']]

# %%
(ggplot(dados) + aes(x = 'valor_aluguel', y= 'bathroom') + 
geom_point(aes(fill = 'city', size = 'aluguel_alto', shape = 'city')))
# Out:
# C:\Users\vitor\Anaconda3\lib\site-packages\plotnine\scales\scale_size.py:50: PlotnineWarning: Using alpha for a discrete variable is not advised.
#   PlotnineWarning
# <ggplot: (-9223371897333249300)>

# %%
sea.FacetGrid(dados.corr())

# %%
(ggplot(dados) + aes(x = 'valor_aluguel', y = 'bathroom') + geom_point() + 
 facet_wrap(facets='city', scales='Free'))
# Out:
# <ggplot: (-9223371897337093808)>

# %%
(ggplot(dados)  +aes(x = 'valor_aluguel')  + 
 geom_histogram(aes(fill = 'city')) + 
 facet_wrap(facets=(['aluguel_alto','city']), nrow=2, ncol=5))
# Out:
# C:\Users\vitor\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 142'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# <ggplot: (-9223371897340762044)>
